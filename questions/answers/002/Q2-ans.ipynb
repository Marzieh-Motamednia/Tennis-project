# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import duckdb

# %%
con = duckdb.connect(r'C:\Users\marzieh\Documents\GitHub\Tennis-project\data\tennis.duckdb')
con.execute("SHOW TABLES").df()
# Out:
# ---------------------------------------------------------------------------
# IOException                               Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 con = duckdb.connect(r'\data\tennis.duckdb')
#       2 con.execute("SHOW TABLES").df()
#
# IOException: IO Error: Cannot open file "data\tennis.duckdb": The system cannot find the path specified.

# %%
query1 = """
    SELECT DISTINCT player_id, height
    FROM match_home_team
    WHERE height IS NOT NULL
"""
query2 = """
    SELECT DISTINCT player_id, height
    FROM match_away_team
    WHERE height IS NOT NULL
"""

# %%
df1 = con.execute(query1).df()
df2 = con.execute(query1).df()

conc = pd.concat([df1,df2], ignore_index=True)
conc
# Out:
#       player_id  height
# 0         32466    1.68
# 1         16683    1.83
# 2         75813    1.93
# 3        329816    1.85
# 4        217464    1.68
# ...         ...     ...
# 2529     113889    1.96
# 2530     321789    1.75
# 2531     155684    1.78
# 2532     272633    1.83
# 2533      41372    1.57
#
# [2534 rows x 2 columns]

# %%
conc['height'].mean()
# Out:
# np.float64(1.822533543804262)
